# %%
# -*- coding: utf-8 -*-
"""Notebook 8 - Final Evaluation, Comparison & Dissertation Outputs.ipynb

FINAL consolidated version. Changes from the version you uploaded:
  - Fixed 3 filename mismatches (engineered_lightgbm_results.csv and
    shap_feature_importance.csv didn't exist; now points at the real
    files Notebook 6b/7 actually save).
  - Added the confusion matrix and fairness evaluation sections that
    didn't exist anywhere in the pipeline before.
  - Removed duplicate cells: two identical "FINAL RESULTS SUMMARY"
    print blocks, two SHAP-loading cells (one used the variable name
    `shap`, which shadows the shap package name - renamed throughout
    to `shap_results`), and two summary-table constructions that had
    silently drifted from each other (different column names and
    different baseline PR-AUC placeholders, producing two saved files
    with inconsistent content for what was supposed to be the same
    table). There is now exactly one summary table, saved consistently
    to both output filenames.
"""

import warnings
warnings.filterwarnings("ignore")

import os
import joblib
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix

from google.colab import drive

drive.mount('/content/drive')

# ============================================================
# Project Directories
# ============================================================

PROJECT_DIR = "/content/drive/MyDrive/Ghana_Dropout_Project"

RESULT_DIR = f"{PROJECT_DIR}/results"
FIGURE_DIR = f"{PROJECT_DIR}/figures"
MODEL_DIR = f"{PROJECT_DIR}/models"
DATA_DIR = f"{PROJECT_DIR}/data"

os.makedirs(RESULT_DIR, exist_ok=True)
os.makedirs(FIGURE_DIR, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(DATA_DIR, exist_ok=True)

# ============================================================
# REQUIRED before the joblib.load() of e_lightgbm_focal_loss_model.pkl
# later in this notebook - do not remove.
#
# LightGBM pickles a custom `objective` function by reference (module
# name + function name), not by value. The model was saved from
# Notebook 6b's own kernel, where focal_loss_lgb was defined directly
# in that notebook - so it pickled as a reference to
# __main__.focal_loss_lgb. This notebook has a separate __main__ with
# no such function, so loading the model fails with AttributeError
# unless the identical function is redefined here first, under the
# identical name (it's never actually called below - it just needs to
# exist so pickle can resolve the reference).
# ============================================================

GAMMA = 2.0
ALPHA = 0.75
EPSILON = 1e-6

def focal_loss_lgb(y_true, y_pred):
    p = 1.0 / (1.0 + np.exp(-y_pred))
    p = np.clip(p, EPSILON, 1.0 - EPSILON)
    pt = np.where(y_true == 1, p, 1.0 - p)
    alpha_t = np.where(y_true == 1, ALPHA, 1.0 - ALPHA)
    grad = alpha_t * (1.0 - pt) ** GAMMA * (p - y_true)
    hess = alpha_t * (1.0 - pt) ** GAMMA * p * (1.0 - p)
    return grad, hess

def focal_loss_eval(y_true, y_pred):
    p = 1.0 / (1.0 + np.exp(-y_pred))
    p = np.clip(p, 1e-7, 1 - 1e-7)
    pt = np.where(y_true == 1, p, 1.0 - p)
    alpha_t = np.where(y_true == 1, ALPHA, 1.0 - ALPHA)
    loss = -alpha_t * (1.0 - pt) ** GAMMA * np.log(pt)
    return "focal_loss", float(np.mean(loss)), False

# ============================================================
# Load Comparison Source Files
# ============================================================

baseline = pd.read_csv(f"{RESULT_DIR}/baseline_cv_results.csv")

augmentation = pd.read_csv(f"{RESULT_DIR}/augmentation_results.csv")

# engineered_lightgbm_results.csv does not exist - Notebook 6b saves
# focal_loss_ablation_results.csv instead, with 3 rows (baseline
# LightGBM, features-only ablation control, and the proposed
# E-LightGBM) and different column names. Load it, keep only the
# proposed model's row, and rename columns to match the convention
# baseline/augmentation already use.
focal_ablation = pd.read_csv(f"{RESULT_DIR}/focal_loss_ablation_results.csv")

engineered = focal_ablation[
    focal_ablation["Model"] == "E-LightGBM (Proposed)"
].copy()

engineered = engineered.rename(columns={
    "Macro_F1": "F1",
    "AUC_ROC": "ROC_AUC",
    "AUC_PR": "PR_AUC"
})

# ============================================================
# Build the Unified Comparison Table
# ============================================================

baseline = baseline.rename(columns={
    "F1": "F1 Score", "ROC_AUC": "ROC-AUC", "PR_AUC": "PR-AUC"
})

augmentation = augmentation.rename(columns={
    "F1": "F1 Score", "ROC_AUC": "ROC-AUC", "PR_AUC": "PR-AUC"
})

augmentation["Model"] = augmentation["Experiment"]

engineered = engineered.rename(columns={
    "F1": "F1 Score", "ROC_AUC": "ROC-AUC", "PR_AUC": "PR-AUC"
})

# Dormant fallback - only fires if `engineered` somehow lacks a Model
# column, which it won't given the filtering above. Left in as a
# defensive guard, not expected to ever trigger.
if "Model" not in engineered.columns:
    engineered.insert(0, "Model", "E-LightGBM (Proposed)")

comparison = pd.concat(
    [baseline, augmentation, engineered],
    ignore_index=True,
    sort=False
)

comparison = comparison[[
    "Model", "Accuracy", "Precision", "Recall", "F1 Score", "ROC-AUC", "PR-AUC"
]]

comparison["Category"] = "Baseline"

comparison.loc[
    comparison["Model"].isin(["Original", "SMOTE", "CTGAN"]),
    "Category"
] = "Augmentation"

comparison.loc[
    comparison["Model"] == "E-LightGBM (Proposed)",
    "Category"
] = "Proposed"

# ============================================================
# Baseline Ranking
# ============================================================

baseline_results = comparison[comparison["Category"] == "Baseline"].copy()

# baseline_cv_results.csv never had a PR-AUC column - Notebook 4's CV
# loop only scores accuracy/precision/recall/f1/roc_auc, so PR-AUC is
# genuinely absent here, not a bug. errors="ignore" handles that.
baseline_results = baseline_results.drop(columns=["PR-AUC"], errors="ignore")

baseline_results = baseline_results.sort_values(
    by=["F1 Score", "ROC-AUC"], ascending=False
).reset_index(drop=True)

baseline_results.insert(0, "Rank", range(1, len(baseline_results) + 1))

display(baseline_results)

baseline_results.to_csv(f"{RESULT_DIR}/baseline_ranking.csv", index=False)

# ============================================================
# Plotting Helper
# ============================================================

def plot_metric(df, metric, title, xmin=None):
    data = df.sort_values(metric)

    plt.figure(figsize=(9, 5))

    bars = plt.barh(data["Model"], data[metric], edgecolor="black")

    if xmin is not None:
        plt.xlim(xmin, 1)

    plt.title(title, fontsize=14, fontweight="bold")
    plt.xlabel(metric)
    plt.grid(axis="x", alpha=.3)

    for bar in bars:
        value = bar.get_width()
        plt.text(value + 0.001, bar.get_y() + bar.get_height() / 2,
                  f"{value:.4f}", va="center")

    plt.tight_layout()

    filename = title.lower().replace(" ", "_").replace("-", "_")

    plt.savefig(f"{FIGURE_DIR}/{filename}.png", dpi=300, bbox_inches="tight")
    plt.show()

plot_metric(baseline_results, "Accuracy", "Baseline Model Accuracy", 0.98)
plot_metric(baseline_results, "F1 Score", "Baseline Model F1 Score", 0.90)
plot_metric(baseline_results, "ROC-AUC", "Baseline ROC-AUC", 0.95)

# ============================================================
# Augmentation Ranking (Original vs SMOTE vs CTGAN)
# ============================================================

augmentation_results = comparison[comparison["Category"] == "Augmentation"].copy()

augmentation_results = augmentation_results.sort_values(
    by=["PR-AUC", "ROC-AUC"], ascending=False
).reset_index(drop=True)

augmentation_results.insert(0, "Rank", range(1, len(augmentation_results) + 1))

display(augmentation_results)

augmentation_results.to_csv(f"{RESULT_DIR}/augmentation_ranking.csv", index=False)

plot_metric(augmentation_results, "Accuracy", "Augmentation Accuracy", 0.99)
plot_metric(augmentation_results, "F1 Score", "Augmentation F1 Score", 0.95)
plot_metric(augmentation_results, "ROC-AUC", "Augmentation ROC-AUC", 0.99)
plot_metric(augmentation_results, "PR-AUC", "Augmentation PR-AUC", 0.95)

# ============================================================
# Proposed Model
# ============================================================

proposed = comparison[comparison["Category"] == "Proposed"].copy()

display(proposed)

proposed.to_csv(f"{RESULT_DIR}/proposed_model_results.csv", index=False)

# ============================================================
# Confusion Matrices: Baseline LightGBM vs E-LightGBM
# ============================================================

baseline_model = joblib.load(f"{MODEL_DIR}/baseline_lightgbm_model.pkl")
focal_model = joblib.load(f"{MODEL_DIR}/e_lightgbm_focal_loss_model.pkl")
config = joblib.load(f"{MODEL_DIR}/e_lightgbm_config.pkl")

RAW_FEATURE_COLS = config["raw_feature_cols"]

X_test = pd.read_csv(f"{DATA_DIR}/X_test_focal.csv")
y_test = pd.read_csv(f"{DATA_DIR}/y_test_focal.csv").squeeze()

def predict_proba_focal(model, X_eval):
    raw_scores = model.predict(X_eval, raw_score=True)
    return 1.0 / (1.0 + np.exp(-raw_scores))

y_prob_baseline = baseline_model.predict_proba(X_test[RAW_FEATURE_COLS])[:, 1]
y_pred_baseline = (y_prob_baseline >= 0.5).astype(int)

y_prob_focal = predict_proba_focal(focal_model, X_test)
y_pred_focal = (y_prob_focal >= 0.5).astype(int)

cm_baseline = confusion_matrix(y_test, y_pred_baseline, normalize="true")
cm_focal = confusion_matrix(y_test, y_pred_focal, normalize="true")

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.heatmap(
    cm_baseline, annot=True, fmt=".3f", cmap="Blues",
    xticklabels=["Retained", "Dropout"], yticklabels=["Retained", "Dropout"],
    ax=axes[0], cbar=True
)
axes[0].set_title("(a) Baseline LightGBM")
axes[0].set_xlabel("Predicted label")
axes[0].set_ylabel("True label")

sns.heatmap(
    cm_focal, annot=True, fmt=".3f", cmap="Greens",
    xticklabels=["Retained", "Dropout"], yticklabels=["Retained", "Dropout"],
    ax=axes[1], cbar=True
)
axes[1].set_title("(b) E-LightGBM (Proposed)")
axes[1].set_xlabel("Predicted label")
axes[1].set_ylabel("True label")

plt.suptitle("Normalized Confusion Matrices (row-normalized, recall per true class)")
plt.tight_layout()

plt.savefig(f"{FIGURE_DIR}/confusion_matrices_comparison.png", dpi=300, bbox_inches="tight")
plt.show()

confusion_summary = pd.DataFrame([{
    "Model": "Baseline LightGBM",
    "TPR": cm_baseline[1, 1], "FPR": cm_baseline[0, 1],
    "TNR": cm_baseline[0, 0], "FNR": cm_baseline[1, 0]
}, {
    "Model": "E-LightGBM (Proposed)",
    "TPR": cm_focal[1, 1], "FPR": cm_focal[0, 1],
    "TNR": cm_focal[0, 0], "FNR": cm_focal[1, 0]
}])

confusion_summary.to_csv(f"{RESULT_DIR}/confusion_matrix_summary.csv", index=False)
display(confusion_summary)

# ============================================================
# Fairness Evaluation
# ============================================================
# COLUMN CONFIG - verify against your actual X_test_focal.csv columns,
# printed below. Neither name is confirmed against your real dataset.
# ============================================================

print(X_test.columns.tolist())

GENDER_COL = "gender"
GEO_ZONE_COL = "geographic_zone"  # <-- verify against the printed list above

FAIRNESS_THRESHOLD = 0.10  # pre-agreed acceptable difference - set and
                            # justify this in Methods Section 2.12
                            # BEFORE looking at these results

def group_tpr_fpr(y_true, y_pred, group_values):
    results = {}
    for g in np.unique(group_values):
        mask = group_values == g
        if mask.sum() == 0:
            continue
        cm = confusion_matrix(y_true[mask], y_pred[mask], labels=[0, 1], normalize="true")
        tpr = cm[1, 1] if not np.isnan(cm[1, 1]) else np.nan
        fpr = cm[0, 1] if not np.isnan(cm[0, 1]) else np.nan
        results[g] = (tpr, fpr, mask.sum())
    return results

def fairness_report(y_true, y_pred, group_series, group_label):
    if group_label not in X_test.columns:
        print(f"WARNING: column '{group_label}' not found - skipping.")
        return None

    group_values = group_series.to_numpy()
    group_stats = group_tpr_fpr(y_true.to_numpy(), y_pred, group_values)

    print(f"\n{group_label} subgroup TPR/FPR:")
    for g, (tpr, fpr, n) in group_stats.items():
        print(f"  Group {g} (n={n}): TPR={tpr:.4f}, FPR={fpr:.4f}")

    groups = list(group_stats.keys())
    if len(groups) < 2:
        print(f"WARNING: fewer than 2 subgroups for {group_label} - cannot compute a difference.")
        return None

    tprs = [group_stats[g][0] for g in groups]
    fprs = [group_stats[g][1] for g in groups]

    eq_opp_diff = np.nanmax(tprs) - np.nanmin(tprs)
    eq_odds_diff = max(np.nanmax(tprs) - np.nanmin(tprs), np.nanmax(fprs) - np.nanmin(fprs))

    print(f"  Equal Opportunity difference: {eq_opp_diff:.4f}")
    print(f"  Equalized Odds difference: {eq_odds_diff:.4f}")
    print(f"  Within {FAIRNESS_THRESHOLD} threshold: {bool(eq_odds_diff <= FAIRNESS_THRESHOLD)}")

    return {
        "Subgroup_Variable": group_label,
        "Equal_Opportunity_Diff": eq_opp_diff,
        "Equalized_Odds_Diff": eq_odds_diff,
        "Within_Threshold": bool(eq_odds_diff <= FAIRNESS_THRESHOLD),
        "N_Groups": len(groups)
    }

fairness_results = []

for col in [GENDER_COL, GEO_ZONE_COL]:
    if col in X_test.columns:
        r = fairness_report(y_test, y_pred_focal, X_test[col], col)
        if r:
            fairness_results.append(r)
    else:
        print(f"WARNING: '{col}' not in X_test_focal.csv - fix the column name above.")

if fairness_results:
    fairness_df = pd.DataFrame(fairness_results)
    display(fairness_df)
    fairness_df.to_csv(f"{RESULT_DIR}/fairness_evaluation.csv", index=False)
else:
    print("No fairness results computed - fix the column names above and re-run this cell.")

# ============================================================
# SHAP Feature Importance (loaded from Notebook 7's output)
# ============================================================

shap_results = pd.read_csv(f"{RESULT_DIR}/feature_importance_focal.csv")

display(shap_results.head(20))

# ============================================================
# Final Summary Table (single definitive version)
# ============================================================
# baseline_results has no PR-AUC column (see note above) - reported as
# NaN here rather than a string placeholder, so it round-trips cleanly
# through CSV/Excel instead of being read back as text.

summary = pd.DataFrame({
    "Category": ["Baseline", "Data Augmentation", "Proposed"],
    "Best Model": [
        baseline_results.iloc[0]["Model"],
        augmentation_results.iloc[0]["Model"],
        proposed.iloc[0]["Model"]
    ],
    "Accuracy": [
        baseline_results.iloc[0]["Accuracy"],
        augmentation_results.iloc[0]["Accuracy"],
        proposed.iloc[0]["Accuracy"]
    ],
    "Precision": [
        baseline_results.iloc[0]["Precision"],
        augmentation_results.iloc[0]["Precision"],
        proposed.iloc[0]["Precision"]
    ],
    "Recall": [
        baseline_results.iloc[0]["Recall"],
        augmentation_results.iloc[0]["Recall"],
        proposed.iloc[0]["Recall"]
    ],
    "F1 Score": [
        baseline_results.iloc[0]["F1 Score"],
        augmentation_results.iloc[0]["F1 Score"],
        proposed.iloc[0]["F1 Score"]
    ],
    "ROC-AUC": [
        baseline_results.iloc[0]["ROC-AUC"],
        augmentation_results.iloc[0]["ROC-AUC"],
        proposed.iloc[0]["ROC-AUC"]
    ],
    "PR-AUC": [
        np.nan,
        augmentation_results.iloc[0]["PR-AUC"],
        proposed.iloc[0]["PR-AUC"]
    ]
})

display(summary)

# Saved under both filenames from the two draft versions, so nothing
# downstream that already references either name breaks - both now
# contain the identical, correct table.
summary.to_csv(f"{RESULT_DIR}/chapter4_summary.csv", index=False)
summary.to_csv(f"{RESULT_DIR}/Table_4_4_Final_Comparison.csv", index=False)

# ============================================================
# Final Excel Workbook
# ============================================================

with pd.ExcelWriter(f"{RESULT_DIR}/final_results.xlsx", engine="openpyxl") as writer:
    baseline_results.to_excel(writer, sheet_name="Baseline Ranking", index=False)
    augmentation_results.to_excel(writer, sheet_name="Augmentation Ranking", index=False)
    proposed.to_excel(writer, sheet_name="Proposed Model", index=False)
    summary.to_excel(writer, sheet_name="Final Comparison", index=False)
    shap_results.to_excel(writer, sheet_name="SHAP Importance", index=False)
    confusion_summary.to_excel(writer, sheet_name="Confusion Matrix Summary", index=False)
    if fairness_results:
        fairness_df.to_excel(writer, sheet_name="Fairness Evaluation", index=False)

print("Excel workbook saved: final_results.xlsx")

# ============================================================
# Final Results Summary (printed once)
# ============================================================

print("=" * 70)
print("FINAL RESULTS SUMMARY")
print("=" * 70)

display(summary)

print("\nBEST BASELINE MODEL")
print("-" * 25)
print(baseline_results.iloc[0])

print("\nBEST AUGMENTATION METHOD")
print("-" * 25)
print(augmentation_results.iloc[0])

print("\nPROPOSED MODEL")
print("-" * 25)
print(proposed.iloc[0])

print("=" * 70)
print("KEY FINDINGS")
print("=" * 70)

print(f"- Best baseline model: {baseline_results.iloc[0]['Model']}")
print(f"- Best augmentation method: {augmentation_results.iloc[0]['Model']}")
print(f"- Proposed model: {proposed.iloc[0]['Model']}")

print(f"\nBest baseline F1 Score: {baseline_results.iloc[0]['F1 Score']:.4f}")
print(f"Best augmentation F1 Score: {augmentation_results.iloc[0]['F1 Score']:.4f}")
print(f"Proposed model F1 Score: {proposed.iloc[0]['F1 Score']:.4f}")

print("\nNotebook 8 completed successfully.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#     Rank                Model  Accuracy  Precision    Recall  F1 Score  \
# 0      1            CTGAN_250     0.995   1.000000  0.944400  0.984300
# 1      2            CTGAN_500     0.995   1.000000  0.944400  0.984300
# 2      3            CTGAN_250     0.995   1.000000  0.944400  0.984300
# 3      4            CTGAN_250     0.995   1.000000  0.944400  0.984300
# 4      5            CTGAN_250     0.995   1.000000  0.944400  0.984300
# 5      6            CTGAN_500     0.995   1.000000  0.944400  0.984300
# 6      7            CTGAN_500     0.995   1.000000  0.944400  0.984300
# 7      8            CTGAN_500     0.990   0.944400  0.944400  0.969500
# 8      9             CatBoost     0.992   0.977709  0.935088  0.955505
# 9     10             LightGBM     0.991   0.969474  0.935088  0.950620
# ...
